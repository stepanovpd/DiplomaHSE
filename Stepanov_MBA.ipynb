# %%
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth
from mlxtend.frequent_patterns import association_rules
import pandas as pd
import numpy as np
import sklearn
import seaborn
from pandas.io.excel import ExcelWriter
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
#from kneed import KneeLocator
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
from sklearn.neighbors import LocalOutlierFactor
from sklearn import preprocessing

# %%
MB1_df = pd.read_excel("mba.xlsx", sheet_name=0).set_index('Phone_new')
MB2_df = pd.read_excel("mba.xlsx", sheet_name=1).set_index('Phone_new')
MB3_df = pd.read_excel("mba.xlsx", sheet_name=2).set_index('Phone_new')
MB4_df = pd.read_excel("mba.xlsx", sheet_name=3).set_index('Phone_new')
MB5_df = pd.read_excel("mba.xlsx", sheet_name=4).set_index('Phone_new')
MB6_df = pd.read_excel("mba.xlsx", sheet_name=5).set_index('Phone_new')
MB7_df = pd.read_excel("mba.xlsx", sheet_name=6).set_index('Phone_new')
MB8_df = pd.read_excel("mba.xlsx", sheet_name=7).set_index('Phone_new')

# %%
MB1_df
# Out:
#                           Аксессуары ТВ-Аудио  Аксессуары для бытовой техники  \
# Phone_new
# 55574848-50555256495077                 False                           False
# 55574848-52564952494974                 False                           False
# 55574848-57525657545078                 False                           False
# 55574850-495051484950755                False                           False
# 55574850-50495652525771                 False                           False
# ...                                       ...                             ...
# 55575654-55545348545377                 False                           False
# 55575654-57524954575179                 False                           False
# 55575655-57515354544876                 False                           False
# 55575656-49535052564879                 False                           False
# 55575757-55575549495372                 False                           False
#
# ...

# %%
frequent_itemsets1 = fpgrowth(MB1_df, min_support=0.001, use_colnames=True)
frequent_itemsets2 = fpgrowth(MB2_df, min_support=0.001, use_colnames=True)
frequent_itemsets3 = fpgrowth(MB3_df, min_support=0.001, use_colnames=True)
frequent_itemsets4 = fpgrowth(MB4_df, min_support=0.001, use_colnames=True)
frequent_itemsets5 = fpgrowth(MB5_df, min_support=0.001, use_colnames=True)
frequent_itemsets6 = fpgrowth(MB6_df, min_support=0.001, use_colnames=True)
frequent_itemsets7 = fpgrowth(MB7_df, min_support=0.001, use_colnames=True)
frequent_itemsets8 = fpgrowth(MB8_df, min_support=0.001, use_colnames=True)

# %%
assr1 = association_rules(frequent_itemsets1, min_threshold=0.001)
assr2 = association_rules(frequent_itemsets2, min_threshold=0.001)
assr3 = association_rules(frequent_itemsets3, min_threshold=0.001)
assr4 = association_rules(frequent_itemsets4, min_threshold=0.001)
assr5 = association_rules(frequent_itemsets5, min_threshold=0.001)
assr6 = association_rules(frequent_itemsets6, min_threshold=0.001)
assr7 = association_rules(frequent_itemsets7, min_threshold=0.001)
assr8 = association_rules(frequent_itemsets8, min_threshold=0.001)

# %%
assr1
# Out:
#                     antecedents                 consequents  \
# 0           (Стиральные машины)  (Холодильное оборудование)
# 1    (Холодильное оборудование)         (Стиральные машины)
# 2                       (Плиты)  (Холодильное оборудование)
# 3    (Холодильное оборудование)                     (Плиты)
# 4           (Стиральные машины)                     (Плиты)
# ..                          ...                         ...
# 147  (Холодильное оборудование)       (Аксессуары ТВ-Аудио)
# 148                     (Плиты)       (Аксессуары ТВ-Аудио)
# 149       (Аксессуары ТВ-Аудио)                     (Плиты)
# 150            (Активный отдых)  (Холодильное оборудование)
# 151  (Холодильное оборудование)            (Активный отдых)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 0              0.456522            0.508152  0.195652    0.428571  0.843392
# 1              0.508152            0.456522  0.195652    0.385027  0.843392
# ...

# %%
assr2
# Out:
#                      antecedents                  consequents  \
# 0               (Электропитание)         (Приготовление пищи)
# 1           (Приготовление пищи)             (Электропитание)
# 2               (Электропитание)         (Красота и здоровье)
# 3           (Красота и здоровье)             (Электропитание)
# 4               (Электропитание)              (Уход за домом)
# ..                           ...                          ...
# 269  (Аксессуары для фото/видео)               (Фотоаппараты)
# 270  (Аксессуары для фото/видео)           (Товары для кухни)
# 271           (Товары для кухни)  (Аксессуары для фото/видео)
# 272        (Носители информации)                (Видеокамеры)
# 273                (Видеокамеры)        (Носители информации)
#
#      antecedent support  consequent support   support  confidence       lift  \
# 0              0.044980            0.135743  0.009639    0.214286   1.578614
# ...

# %%
assr3
# Out:
#                             antecedents                          consequents  \
# 0             (Велосипеды и аксессуары)                   (Тяжелая атлетика)
# 1                    (Тяжелая атлетика)            (Велосипеды и аксессуары)
# 2   (Аксессуары для спортивных товаров)            (Велосипеды и аксессуары)
# 3             (Велосипеды и аксессуары)  (Аксессуары для спортивных товаров)
# 4                    (Тяжелая атлетика)                              (Плиты)
# ..                                  ...                                  ...
# 69             (Прогулки и путешествие)            (Велосипеды и аксессуары)
# 70                          (Тренажеры)                           (Текстиль)
# 71                           (Текстиль)                          (Тренажеры)
# 72                   (Тяжелая атлетика)                   (Товары для кухни)
# 73                   (Товары для кухни)                   (Тяжелая атлетика)
#
# ...

# %%
assr4
# Out:
#                  antecedents               consequents  antecedent support  \
# 0                  (Игрушки)  (Прогулки и путешествие)            0.307692
# 1   (Прогулки и путешествие)                 (Игрушки)            0.549451
# 2                  (Игрушки)      (Приготовление пищи)            0.307692
# 3       (Приготовление пищи)                 (Игрушки)            0.142857
# 4       (Приготовление пищи)  (Прогулки и путешествие)            0.142857
# ..                       ...                       ...                 ...
# 69         (Детская комната)             (Увлажнители)            0.263736
# 70         (Автоэлектроника)                 (Игрушки)            0.010989
# 71                 (Игрушки)         (Автоэлектроника)            0.307692
# 72               (Хозтовары)  (Прогулки и путешествие)            0.010989
# 73  (Прогулки и путешествие)               (Хозтовары)            0.549451
#
# ...

# %%
assr5
# Out:
#                 antecedents            consequents  antecedent support  \
# 0           (Уход за домом)   (Приготовление пищи)            0.088421
# 1      (Приготовление пищи)        (Уход за домом)            0.200000
# 2           (Уход за домом)            (Хозтовары)            0.088421
# 3               (Хозтовары)        (Уход за домом)            0.091228
# 4           (Уход за домом)     (Товары для кухни)            0.088421
# ...                     ...                    ...                 ...
# 1103  (Вентиляторы бытовые)          (Увлажнители)            0.006316
# 1104               (Ванная)           (Сантехника)            0.002105
# 1105           (Сантехника)               (Ванная)            0.046316
# 1106  (Носители информации)          (Видеокамеры)            0.092632
# 1107          (Видеокамеры)  (Носители информации)            0.001404
#
#       consequent support   support  confidence       lift  leverage  \
# ...

# %%
assr6
# Out:
#                     antecedents                  consequents  \
# 0   (Силовая и садовая техника)                (Инструменты)
# 1                 (Инструменты)  (Силовая и садовая техника)
# 2                   (Хозтовары)                (Инструменты)
# 3                 (Инструменты)                  (Хозтовары)
# 4                   (Хозтовары)                 (Сантехника)
# ..                          ...                          ...
# 79  (Силовая и садовая техника)            (Водонагреватели)
# 80                     (Фитнес)                 (Сантехника)
# 81                 (Сантехника)                     (Фитнес)
# 82                       (Свет)                (Инструменты)
# 83                (Инструменты)                       (Свет)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.434343            0.505051  0.202020    0.465116  0.920930
# 1             0.505051            0.434343  0.202020    0.400000  0.920930
# ...

# %%
assr7
# Out:
#                                 antecedents  \
# 0                          (Электропитание)
# 1                          (Телевизоры LCD)
# 2                             (Аудио-Видео)
# 3                          (Электропитание)
# 4                          (Телевизоры LCD)
# ..                                      ...
# 59                         (Телевизоры LCD)
# 60        (DVD/Blu-Ray плееры и компоненты)
# 61                         (Аудиомагнитолы)
# 62  (Аксессуары для смартфонов и планшетов)
# 63                            (Аудио-Видео)
#
#                                 consequents  antecedent support  \
# 0                          (Телевизоры LCD)            0.060345
# 1                          (Электропитание)            0.896552
# 2                          (Электропитание)            0.086207
# 3                             (Аудио-Видео)            0.060345
# 4                     (Аксессуары ТВ-Аудио)            0.896552
# ...

# %%
assr8
# Out:
#                    antecedents                 consequents  \
# 0                        (СВЧ)        (Приготовление пищи)
# 1         (Приготовление пищи)                       (СВЧ)
# 2              (Уход за домом)                       (СВЧ)
# 3                        (СВЧ)             (Уход за домом)
# 4                        (СВЧ)        (Красота и здоровье)
# 5         (Красота и здоровье)                       (СВЧ)
# 6       (Встраиваемая техника)                       (СВЧ)
# 7                        (СВЧ)      (Встраиваемая техника)
# 8       (Встраиваемая техника)        (Приготовление пищи)
# 9         (Приготовление пищи)      (Встраиваемая техника)
# 10      (Встраиваемая техника)             (Уход за домом)
# 11             (Уход за домом)      (Встраиваемая техника)
# 12             (Уход за домом)        (Приготовление пищи)
# 13        (Приготовление пищи)             (Уход за домом)
# 14             (Уход за домом)        (Красота и здоровье)
# ...
